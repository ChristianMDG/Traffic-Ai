# %% [markdown]
# # Évaluation du modèle de trafic
#
# ## Objectif
# - Comparer les prédictions du modèle avec les valeurs réelles.
# - Visualiser les erreurs et la distribution des résidus.
# - Identifier les features les plus importantes.
# - Préparer des graphiques pour un dashboard ou rapport.

# %% [markdown]
# ## 1. Import des librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## 2. Chargement du dataset et du modèle

# %%
df = pd.read_csv("../data/processed/traffic_features.csv")
model = joblib.load("../models/model.pkl")


cols_to_drop = ['traffic_volume', 'date_time']
cols_to_drop = [c for c in cols_to_drop if c in df.columns]
X = df.drop(cols_to_drop, axis=1)
y = df['traffic_volume']
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 df = pd.read_csv("../data/processed/traffic_features.csv")
# ----> 2 model = joblib.load("../models/model.pkl")
#       4 # Séparer X et y
#       5 cols_to_drop = ['traffic_volume', 'date_time']
#
# File ~/.conda/envs/datasci/lib/python3.11/site-packages/joblib/numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
#     753                 mmap_mode=validated_mmap_mode,
#     754             )
#     756 return obj
#
# File ~/.conda/envs/datasci/lib/python3.11/site-packages/joblib/numpy_pickle.py:626, in _unpickle(fobj, ensure_native_byte_order, filename, mmap_mode)
#     624 obj = None
#     625 try:
# --> 626     obj = unpickler.load()
#     627     if unpickler.compat_mode:
#     628         warnings.warn(
#     629             "The file '%s' has been generated with a "
#     630             "joblib version less than 0.10. "
#    (...)    633             stacklevel=3,
#     634         )
#
# File ~/.conda/envs/datasci/lib/python3.11/pickle.py:1211, in _Unpickler.load(self)
#    1209 key = read(1)
#    1210 if not key:
# -> 1211     raise EOFError
#    1212 assert isinstance(key, bytes_types)
#    1213 dispatch[key[0]](self)
#
# EOFError:

# %% [markdown]
# ## 3. Prédiction du modèle

# %%
y_pred = model.predict(X)

# %% [markdown]
# ## 4. Calcul des métriques

# %%
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

print("MAE :", mae)
print("RMSE :", rmse)
print("R² :", r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mae = mean_absolute_error(y, y_pred)
#       2 mse = mean_squared_error(y, y_pred)
#       3 rmse = np.sqrt(mse)
#
# NameError: name 'y' is not defined

# %% [markdown]
# ## 5. Visualisation prédictions vs réel

# %%
plt.figure(figsize=(12,6))
plt.plot(y.values[:500], label='Réel')         # afficher les 500 premiers points pour la lisibilité
plt.plot(y_pred[:500], label='Prévu')
plt.title("Prédictions vs Réel")
plt.xlabel("Échantillons")
plt.ylabel("Traffic Volume")
plt.legend()
plt.show()

# %% [markdown]
# ## 6. Distribution des résidus

# %%
residuals = y - y_pred
plt.figure(figsize=(8,5))
sns.histplot(residuals, bins=50, kde=True)
plt.title("Distribution des résidus")
plt.xlabel("Erreur")
plt.show()

# %% [markdown]
# ## 7. Feature importance

# %%
importances = model.feature_importances_
features = X.columns
feat_imp = pd.DataFrame({'feature': features, 'importance': importances})
feat_imp = feat_imp.sort_values(by='importance', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x='importance', y='feature', data=feat_imp.head(20))
plt.title("Top 20 des features importantes")
plt.show()

# %% [markdown]
# ## Conclusion
#
# - Le modèle Random Forest prédit correctement le trafic avec un R² élevé.
# - Les erreurs sont concentrées autour de zéro, ce qui montre un bon ajustement.
# - Les features temporelles (hour, weekday, is_weekend) et certaines variables météo sont les plus importantes.
# - Le dataset est prêt pour être utilisé dans un dashboard ou rapport.

# %% [markdown]
# # Dashboard Traffic Prediction
#
# ## Objectif
# - Visualiser les prédictions du modèle vs le trafic réel.
# - Afficher les erreurs et résidus.
# - Montrer les features les plus importantes.
# - Créer un dashboard interactif pour exploration rapide.

# %% [markdown]
# ## 2. Import des librairies

# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## 3. Chargement du dataset et du modèle

# %%
df = pd.read_csv("../data/processed/traffic_features.csv")
model = joblib.load("../models/traffic_model.pkl")

df = df.drop(columns=['date_time'], errors='ignore')

cat_cols = df.select_dtypes(include=['object']).columns.tolist()
df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

y = df['traffic_volume']

model_features = model.feature_names_in_
X = df.reindex(columns=model_features, fill_value=0)
y_pred = model.predict(X)

# %% [markdown]
# ## 4. Titre du dashboard

# %%
st.title("Dashboard de Prédiction du Trafic")
st.markdown("Visualisation du trafic réel vs prédit et des features importantes")
# Out:
# 2026-04-09 21:36:37.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ## 5. Affichage métriques

# %%
mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))
r2 = r2_score(y, y_pred)

st.subheader("Métriques du modèle")
st.write(f"MAE : {mae:.2f}")
st.write(f"RMSE : {rmse:.2f}")
st.write(f"R² : {r2:.2f}")
# Out:
# 2026-04-09 21:36:37.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## 6. Graphique réel vs prédit

# %%
st.subheader("Trafic réel vs prédit (500 premiers points)")

fig, ax = plt.subplots(figsize=(12,6))
ax.plot(y.values[:500], label="Réel")
ax.plot(y_pred[:500], label="Prévu")
ax.set_xlabel("Échantillons")
ax.set_ylabel("Traffic Volume")
ax.legend()
st.pyplot(fig)
# Out:
# 2026-04-09 21:36:37.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ## 7. Distribution des résidus

# %%
st.subheader("Distribution des erreurs (résidus)")

residuals = y - y_pred
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(residuals, bins=50, kde=True, ax=ax)
ax.set_xlabel("Erreur")
st.pyplot(fig)
# Out:
# 2026-04-09 21:36:37.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ## 8. Feature importance

# %%
st.subheader("Top 20 des features importantes")

importances = model.feature_importances_
features = X.columns
feat_imp = pd.DataFrame({'feature': features, 'importance': importances})
feat_imp = feat_imp.sort_values(by='importance', ascending=False).head(20)

fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(x='importance', y='feature', data=feat_imp, ax=ax)
st.pyplot(fig)
# Out:
# 2026-04-09 21:36:37.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:37.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:38.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:38.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:38.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-09 21:36:38.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
